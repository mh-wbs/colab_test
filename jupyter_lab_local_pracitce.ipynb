# %%
import sys

# %%
print(sys.executable)
# Out:
# C:\Users\lutki\anaconda3\envs\pandas_project\python.exe

# %%
test = "hello"

# %%
print(test)
# Out:
# hello

# %%
import jupyter_client
from jupyter_client.kernelspec import KernelSpecManager
ksm = KernelSpecManager()
print(ksm.get_kernel_spec("practicing_env").resource_dir)
# Out:
# C:\Users\lutki\AppData\Roaming\jupyter\kernels\practicing_env

# %%
# let´s add code to practice git
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2
