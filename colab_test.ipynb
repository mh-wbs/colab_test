# %% [markdown]
# <a href="https://colab.research.google.com/github/mh-wbs/colab_test/blob/main/colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Is this working?")
# Out:
# Is this working?

# %%
print("interesting")
# Out:
# interesting
